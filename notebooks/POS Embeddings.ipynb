# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import spacy
import pandas as pd

# %%
train_df = pd.read_csv('../dataset/train.csv')
test_df = pd.read_csv('../dataset/test.csv')

# %%
nlp = spacy.load('en', disable=['ner', 'parser'])

# %%
toxic_comments = train_df.comment_text.loc[train_df.toxic.nonzero()]

# %%
toxic_comments.str
# Out:
# 6              COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 12        Hey... what is it..\n@ | talk .\nWhat is it......
# 16        Bye! \n\nDon't look, come or think of comming ...
# 42        You are gay or antisemmitian? \n\nArchangel WH...
# 43                 FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!
# 44        I'm Sorry \n\nI'm sorry I screwed around with ...
# 51        GET FUCKED UP. GET FUCKEEED UP.  GOT A DRINK T...
# 55        Stupid peace of shit stop deleting my stuff as...
# 56        =Tony Sidaway is obviously a fistfuckee. He lo...
# 58        My Band Page's deletion. You thought I was gon...
# 59        Why can't you believe how fat Artie is? Did yo...
# 65        All of my edits are good.  Cunts like you who ...
# 79        Hi! I am back again!\nLast warning!\nStop undo...
# 86        Would you both shut up, you don't run wikipedi...
# 105              A pair of jew-hating weiner nazi schmucks.
# 151       "\n\nSORRY PUCK BUT NO ONE EVER SAID DICK WAS ...
# ...

# %%
train_comments = train_df.comment_text.astype(str)

# %%
pos_comment_text = []

for doc in nlp.pipe(train_comments[:10], batch_size=10000, n_threads=3):
    pos_comment_text.append(list((map(lambda token: (token.text, token.tag_), doc))))

# %%
pos_comment_text
# Out:
# [[('Explanation', 'NNP'),
#   ('\n', ''),
#   ('Why', 'WRB'),
#   ('the', 'DT'),
#   ('edits', 'NNS'),
#   ('made', 'VBN'),
#   ('under', 'IN'),
#   ('my', 'PRP$'),
#   ('username', 'NN'),
#   ('Hardcore', 'NNP'),
#   ('Metallica', 'NNP'),
#   ('Fan', 'NNP'),
#   ('were', 'VBD'),
#   ('reverted', 'VBN'),
#   ('?', '.'),
#   ('They', 'PRP'),
#   ('were', 'VBD'),
#   ("n't", 'RB'),
#   ('vandalisms', 'NNS'),
#   (',', ','),
#   ('just', 'RB'),
#   ('closure', 'VB'),
#   ('on', 'IN'),
#   ('some', 'DT'),
#   ('GAs', 'NN'),
#   ('after', 'IN'),
#   ('I', 'PRP'),
#   ('voted', 'VBD'),
#   ('at', 'IN'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('Dolls', 'NNP'),
#   ('FAC', 'NNP'),
#   ('.', '.'),
#   ('And', 'CC'),
#   ('please', 'UH'),
#   ('do', 'VB'),
#   ("n't", 'RB'),
#   ('remove', 'VB'),
#   ('the', 'DT'),
#   ('template', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('talk', 'NN'),
#   ('page', 'NN'),
#   ('since', 'IN'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
# ...

# %%
spacy.explain
# Out:
# <function spacy.glossary.explain>
